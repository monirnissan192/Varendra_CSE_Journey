# %% [markdown]
# Print we do

# %%
print('192')
# Out:
# 192

# %% [markdown]
# Print Name,Id,Studency,Sec

# %%
name='Nissan'
id=232311192
Is_student=True
Sec='E'

print(type(name))
print(type(id))
print(type(Is_student))
print(type(Sec))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# Input Take

# %%
Semester=input("Enter your Semester:" )
print("Your Semester is:",Semester)
# Out:
# Your Semester is: 7th

# %% [markdown]
# If I run this, that is not running cause in a python if we not declare the input type pythong take this input as String

# %%
num1=input("Enter first number:")
num2=input("Enter Second number:")
sum=num1+num2
print("The sum of two numbers is:",sum)

# %% [markdown]
# That's like type declair

# %%
num1=int(input("Enter first number:"))
num2=int(input("Enter first number:"))
sum=(num1+num2)
print("The sum of two numbers is:",sum)
# Out:
# The sum of two numbers is: 2

# %% [markdown]
# Array Declaration

# %%
Student_Ids=[192,162,163,170,177,196,197,195]
print(Student_Ids)
print(type(Student_Ids))
print(Student_Ids[1])
# Out:
# [192, 162, 163, 170, 177, 196, 197, 195]
# <class 'list'>
# 162

# %% [markdown]
# That's Like Id is append

# %%
Student_Ids.append(193)
print(Student_Ids)
# Out:
# [192, 162, 163, 170, 177, 196, 197, 195, 193, 175, 193]

# %% [markdown]
# In My Previous 10 number possition there is nothing but I insert this in 10th possition 175

# %%
Student_Ids.insert(10,175)
print(Student_Ids)
# Out:
# [192, 162, 163, 170, 177, 196, 197, 195, 193, 175]

# %% [markdown]
# In My Previous Array two 193 is here but to used remove i removed 193. From the left to write which is come at the first that is removed not at last,Middle or just at the first which see that is delete. remove() is for VALUES (.removed is removed the value of array)

# %%
Student_Ids.remove(193)
print(Student_Ids)
# Out:
# [192, 162, 163, 170, 177, 196, 197, 195, 175, 193]

# %% [markdown]
# Here the working of pop.Pop is  working to removed the Possition index.Like 192, 162, 163, 170, 177, 196, 197, 195, 175, 193 here if I pop index(10) then my 10 posstion has which value  here that is delete that's mean 193 delete

# %%
Student_Ids.pop(9)
print(Student_Ids)
# Out:
# [192, 162, 163, 170, 177, 196, 197, 195, 175]

# %%
length=len(Student_Ids)
print(length)
# Out:
# 9
